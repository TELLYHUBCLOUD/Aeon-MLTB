# %% [markdown]
# # 🚀 Aeon-MLTB Heroku Deployment (Main Branch)
#
# <div align="center">
#   <img src='https://github.com/5hojib/5hojib/raw/main/images/Aeon-MLTB.gif' height="250" width="500" alt="Aeon-MLTB"/>
#   <h2>⚡ Streamlined & Feature-Rich Bot Deployment ⚡</h2>
# </div>
#
# ---
#
# ## 📋 Project Information
#
# | **Detail** | **Information** |
# |------------|----------------|
# | 🔗 **Repository** | [AeonOrg/Aeon-MLTB](https://github.com/AeonOrg/Aeon-MLTB) |
# | 🌿 **Branch** | `main` |
# | 📚 **Documentation** | [Deployment Docs](https://github.com/AeonOrg/Aeon-MLTB/tree/main/docs) |
# | 💬 **Support** | [Aeon Discussion](https://t.me/AeonDiscussion) |
# | 🏷️ **Features** | Stable Release, Core Functionality |
#
# ---
#
# ## 🎯 Quick Heroku Deployment Guide
#
# > **Note:** This notebook deploys the **main branch** (stable release) of Aeon-MLTB to Heroku using Google Colab.
# > For the latest features, use the extended branch version instead.
# > Follow the cells in order for a successful deployment.

# %%
# @title <center><h2>🔐 Heroku Authentication</h2></center><br>

# @markdown <div align="center"><h3>🔑 Login to your Heroku account</h3></div>
# @markdown <p align="center"><i>Enter your Heroku credentials to authenticate</i></p>

# @markdown ---

Heroku_Email = ""  # @param {type:"string"}
# @markdown <small>Your Heroku account email address</small>

Heroku_API = ""  # @param {type:"string"}
# @markdown <small>Your Heroku API Key - Get from [Account Settings](https://dashboard.heroku.com/account)</small>

# @markdown <div align="center"><small><b>💡 Tip:</b> For team deployments, use your personal API token</small></div>

# @markdown ---

# !curl -s https://cli-assets.heroku.com/install.sh | sh

from IPython.display import HTML, clear_output, display

clear_output()
display(
    HTML(
        "<div style='text-align: center; color: green; font-weight: bold;'>✅ Heroku CLI Installed Successfully!</div>"
    )
)

if not all([Heroku_Email, Heroku_API]):
    raise ValueError("❌ Please fill in all required Heroku credentials.")

from os import chmod
from os import path as ospath

netrc_path = ospath.expanduser("~/.netrc")

netrc_creds = f"""machine api.heroku.com
  login {Heroku_Email}
  password {Heroku_API}
machine git.heroku.com
  login {Heroku_Email}
  password {Heroku_API}"""
with open(netrc_path, "w") as netrc_file:
    netrc_file.write(netrc_creds)

chmod(netrc_path, 0o600)

# !git config --global user.email {Heroku_Email}
# !git config --global user.name "Aeon-MLTB-Deploy"

display(
    HTML(
        "<div style='text-align: center; color: green; font-weight: bold;'>🎉 Heroku Authentication Complete!</div>"
    )
)

# %%
# @title <center><h2>🏗️ Create Heroku Application</h2></center><br>

# @markdown <div align="center"><h3>📱 Set up your new Heroku app</h3></div>
# @markdown <p align="center"><i>Configure your app name, region, and team settings</i></p>

# @markdown ---

App_Name = "sfwaeonaug1"  # @param {type:"string"}
# @markdown <small>App name (optional - leave empty for random name)</small>

Server_Region = "eu"  # @param ["eu", "us"] {allow-input: true}
# @markdown <small>Server region: EU (Europe) or US (United States)</small>

HK_Team_Name = "suspended"  # @param {type:"string"}
# @markdown <small>Team name (optional - only for team deployments)</small>

# @markdown ---

HK_Team_Name = f"--team {HK_Team_Name}" if HK_Team_Name else ""
# !heroku create --region $Server_Region --stack container $HK_Team_Name $App_Name
# Out:
# Creating ⬢ sfwaeonaug1...
# Creating ⬢ sfwaeonaug1... ⣾
# Creating ⬢ sfwaeonaug1... ⣽
# Creating ⬢ sfwaeonaug1... ⣻
# Creating ⬢ sfwaeonaug1... ⢿
# Creating ⬢ sfwaeonaug1... done, region is eu, stack is container
# https://sfwaeonaug1-efdc5dc17ac0.herokuapp.com/ | https://git.heroku.com/sfwaeonaug1.git

# %%
# @title <center><h2>🔧 Aeon-MLTB Configuration Setup</h2></center><br>

# @markdown <div align="center"><h3>📝 Essential Bot Configuration</h3></div>
# @markdown <p align="center"><i>Fill in the required variables below to configure your Aeon-MLTB bot</i></p>

# @markdown ---

# @markdown ### 🤖 **Bot Credentials** *(Required)*
BOT_TOKEN = "7887960399:AAGWy9DppU4P6T4sV6FqvNamemcbHKnmyMk"  # @param {type:"string"}
# @markdown <small>Get this from [@BotFather](https://t.me/BotFather)</small>

OWNER_ID = 7716048556  # @param {type:"integer"}
# @markdown <small>Your Telegram User ID (not username) - Get from [@userinfobot](https://t.me/userinfobot)</small>

# @markdown ### 📱 **Telegram API** *(Required)*
TELEGRAM_API = 23241238  # @param {type:"integer"}
TELEGRAM_HASH = "e6ff6e3068dbea75500865ac49c3608f"  # @param {type:"string"}
# @markdown <small>Get both from [my.telegram.org](https://my.telegram.org)</small>

# @markdown ### 🗄️ **Database & Storage** *(Required)*
DATABASE_URL = "mongodb+srv://tellymirror:bot@tellymirror.6euwucp.mongodb.net/?retryWrites=true&w=majority&appName=TellyMirror"  # @param {type:"string"}
# @markdown <small>MongoDB connection string for storing bot data</small>

BASE_URL = "https://sfwaeonaug1-efdc5dc17ac0.herokuapp.com"  # @param {type:"string"}
# @markdown <small>Your app's base URL (will be auto-filled after deployment)</small>

# @markdown ### 🔄 **Repository Settings** *(Auto-configured)*
UPSTREAM_REPO = "https://github.com/TELLYHUBCLOUD/Aeon-MLTB"  # @param {type:"string"})
UPSTREAM_BRANCH = "main"  # @param {type:"string"}

# @markdown ---

if not all(
    [
        BOT_TOKEN,
        TELEGRAM_API,
        TELEGRAM_HASH,
        OWNER_ID,
        UPSTREAM_REPO,
        DATABASE_URL,
        BASE_URL,
    ]
):
    raise ValueError("❌ Please fill in all mandatory configuration variables.")

print("📥 Cloning Aeon-MLTB repository...")
# !git clone https://github.com/TELLYHUBCLOUD/Aeon-MLTB
# %cd Aeon-MLTB
# !git checkout deploy_main

print("📝 Creating configuration file...")
config_creds = (
    f'BOT_TOKEN = "{BOT_TOKEN}"\n'
    f"TELEGRAM_API = {TELEGRAM_API}\n"
    f'TELEGRAM_HASH = "{TELEGRAM_HASH}"\n'
    f"OWNER_ID = {OWNER_ID}\n"
    f'UPSTREAM_REPO = "{UPSTREAM_REPO}"\n'
    f'UPSTREAM_BRANCH = "{UPSTREAM_BRANCH}"\n'
    f'DATABASE_URL = "{DATABASE_URL}"\n'
    f'BASE_URL = "{BASE_URL}"\n'
)

# Create config.py file (not config.env)
with open("config.py", "w") as config_file:
    config_file.write(config_creds)

print("✅ Configuration file (config.py) created successfully!")
# Out:
# 📥 Cloning Aeon-MLTB repository...
# Cloning into 'Aeon-MLTB'...
# remote: Enumerating objects: 5845, done.
# remote: Counting objects: 100% (735/735), done.
# remote: Compressing objects: 100% (326/326), done.
# remote: Total 5845 (delta 566), reused 409 (delta 409), pack-reused 5110 (from 5)
# Receiving objects: 100% (5845/5845), 53.31 MiB | 31.83 MiB/s, done.
# Resolving deltas: 100% (3932/3932), done.
# /content/Aeon-MLTB
# Branch 'deploy_main' set up to track remote branch 'deploy_main' from 'origin'.
# Switched to a new branch 'deploy_main'
# 📝 Creating configuration file...
# ✅ Configuration file (config.py) created successfully!

# %%
# @title <center><h2>🚀 Deploy to Heroku</h2></center><br>

# @markdown <div align="center"><h3>🎯 Final deployment step</h3></div>
# @markdown <p align="center"><i>Push your configured bot to Heroku</i></p>

# @markdown ---

App_Name = "sfwaeonaug1"  # @param {type:"string"}
# @markdown <small>Enter the same app name from step 2</small>

# @markdown ---

print("📦 Preparing deployment...")
# !git add . -f
# !git commit -m "🚀 Aeon-MLTB Heroku Deployment Setup (Main Branch)"
# !heroku git:remote -a {App_Name}

print("🚀 Deploying to Heroku...")
# !git push heroku deploy_main:main -f
# !heroku ps:type web=standard-2x -a {App_Name}

print("🎉 Deployment completed! Your Aeon-MLTB bot should be starting up.")
# Out:
# 📦 Preparing deployment...
# On branch deploy_main
# Your branch is ahead of 'origin/deploy_main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# set git remote heroku to https://git.heroku.com/sfwaeonaug1.git
# 🚀 Deploying to Heroku...
# Enumerating objects: 1647, done.
# Counting objects: 100% (1647/1647), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (667/667), done.
# Writing objects: 100% (1647/1647), 973.47 KiB | 31.40 MiB/s, done.
# Total 1647 (delta 1020), reused 1543 (delta 959), pack-reused 0
# remote: Resolving deltas: 100% (1020/1020), done.
# remote: Updated 21 paths from 7a843b5
# remote: Compressing source files... done.
# remote: Building source:
# remote: === Fetching app code
# remote:
# remote: === Building web (Dockerfile)
# remote:
# remote:
# remote: Step 1/8 : FROM 5hojib/aeon:latest
# remote: latest: Pulling from 5hojib/aeon
# remote: 1b3c8f62d074: Pulling fs layer
# remote: 5cb89755c3f9: Pulling fs layer
# remote: 066296d40cf5: Pulling fs layer
# remote: 5cb89755c3f9: Verifying Checksum
# remote: 5cb89755c3f9: Download complete
# remote: 1b3c8f62d074: Verifying Checksum
# remote: 1b3c8f62d074: Download complete
# remote: 1b3c8f62d074: Pull complete
# remote: 5cb89755c3f9: Pull complete
# remote: 066296d40cf5: Verifying Checksum
# remote: 066296d40cf5: Download complete
# remote: 066296d40cf5: Pull complete
# remote: Digest: sha256:22b7e37b33d73fd6da52db7c3cc4a823c49c289d3c1865504b547a7df340e802
# remote: Status: Downloaded newer image for 5hojib/aeon:latest
# remote:  ---> 70ca7c03b59c
# remote: Step 2/8 : WORKDIR /usr/src/app
# remote:  ---> Running in 5be080bf8392
# remote: Removing intermediate container 5be080bf8392
# remote:  ---> f639e8a363a1
# remote: Step 3/8 : RUN chmod 777 /usr/src/app
# remote:  ---> Running in 02a566053061
# remote: Removing intermediate container 02a566053061
# remote:  ---> 9f6efe20c0c2
# remote: Step 4/8 : RUN uv venv
# remote:  ---> Running in 9b09f4c8ee4d
# remote: Using CPython 3.13.3 interpreter at: /usr/bin/python
# remote: Creating virtual environment at: .venv
# remote: Removing intermediate container 9b09f4c8ee4d
# remote:  ---> 54867ddfc8fe
# remote: Step 5/8 : COPY requirements.txt .
# remote:  ---> 43ecc6e41047
# remote: Step 6/8 : RUN uv pip install --no-cache-dir -r requirements.txt
# remote:  ---> Running in 0445e971b9e3
# remote: Resolved 99 packages in 1.16s
# remote: Downloading language-data (5.1MiB)
# remote: Downloading aiohttp (1.6MiB)
# remote: Downloading pydantic-core (1.9MiB)
# remote: Downloading google-api-python-client (13.3MiB)
# remote: Downloading lxml (5.0MiB)
# remote: Downloading marisa-trie (1.2MiB)
# remote: Downloading pyrofork (4.8MiB)
# remote: Downloading brotli (2.8MiB)
# remote: Downloading pycryptodomex (2.2MiB)
# remote: Downloading pillow (6.3MiB)
# remote: Downloading curl-cffi (7.9MiB)
# remote: Downloading uvloop (4.5MiB)
# remote: Downloading yt-dlp (3.1MiB)
# remote: Downloading tdjson (14.7MiB)
# remote: Downloading pymongo (1.9MiB)
# remote:    Building pyaes==1.6.1
# remote:    Building pytdbot==0.9.5
# remote:    Building sgmllib3k==1.0.0
# remote:    Building pyshorteners==1.0.1
# remote:  Downloading marisa-trie
# remote:  Downloading aiohttp
# remote:  Downloading pydantic-core
# remote:  Downloading pymongo
# remote:  Downloading brotli
# remote:  Downloading pycryptodomex
# remote:       Built sgmllib3k==1.0.0
# remote:       Built pyshorteners==1.0.1
# remote:       Built pyaes==1.6.1
# remote:  Downloading uvloop
# remote:       Built pytdbot==0.9.5
# remote:  Downloading lxml
# remote:  Downloading pillow
# remote:  Downloading curl-cffi
# remote:  Downloading language-data
# remote:  Downloading tdjson
# remote:  Downloading yt-dlp
# remote:  Downloading google-api-python-client
# remote:  Downloading pyrofork
# remote: Prepared 99 packages in 1.38s
# remote: Installed 99 packages in 78ms
# remote:  + aio-pika==9.5.7
# remote:  + aioaria2==1.3.6
# remote:  + aiofiles==24.1.0
# remote:  + aiohappyeyeballs==2.6.1
# remote:  + aiohttp==3.12.15
# remote:  + aioqbt==1.0.0
# remote:  + aiormq==6.9.0
# remote:  + aioshutil==1.5
# remote:  + aiosignal==1.4.0
# remote:  + annotated-types==0.7.0
# remote:  + anyio==4.10.0
# remote:  + anytree==2.13.0
# remote:  + apscheduler==3.11.0
# remote:  + asyncio==4.0.0
# remote:  + attrs==25.3.0
# remote:  + brotli==1.1.0
# remote:  + cachetools==5.5.2
# remote:  + certifi==2025.8.3
# remote:  + cffi==1.17.1
# remote:  + charset-normalizer==3.4.3
# remote:  + click==8.2.1
# remote:  + cloudscraper==1.2.71
# remote:  + curl-cffi==0.13.0
# remote:  + deepdiff==8.6.0
# remote:  + dnspython==2.7.0
# remote:  + electrocrypto==2.0.1
# remote:  + fastapi==0.116.1
# remote:  + feedparser==6.0.11
# remote:  + frozenlist==1.7.0
# remote:  + google-api-core==2.25.1
# remote:  + google-api-python-client==2.179.0
# remote:  + google-auth==2.40.3
# remote:  + google-auth-httplib2==0.2.0
# remote:  + google-auth-oauthlib==1.2.2
# remote:  + googleapis-common-protos==1.70.0
# remote:  + gunicorn==23.0.0
# remote:  + h11==0.16.0
# remote:  + httpcore==1.0.9
# remote:  + httplib2==0.22.0
# remote:  + httpx==0.28.1
# remote:  + idna==3.10
# remote:  + jinja2==3.1.6
# remote:  + langcodes==3.5.0
# remote:  + language-data==1.3.0
# remote:  + lxml==6.0.1
# remote:  + marisa-trie==1.3.0
# remote:  + markupsafe==3.0.2
# remote:  + motor==3.7.1
# remote:  + multidict==6.6.4
# remote:  + mutagen==1.47.0
# remote:  + natsort==8.4.0
# remote:  + oauthlib==3.3.1
# remote:  + orderly-set==5.5.0
# remote:  + packaging==25.0
# remote:  + pamqp==3.3.0
# remote:  + pillow==11.3.0
# remote:  + propcache==0.3.2
# remote:  + proto-plus==1.26.1
# remote:  + protobuf==6.32.0
# remote:  + psutil==7.0.0
# remote:  + pyaes==1.6.1
# remote:  + pyasn1==0.6.1
# remote:  + pyasn1-modules==0.4.2
# remote:  + pycparser==2.22
# remote:  + pycryptodomex==3.23.0
# remote:  + pydantic==2.11.7
# remote:  + pydantic-core==2.33.2
# remote:  + pymediainfo-pyrofork==6.0.2
# remote:  + pymongo==4.14.1
# remote:  + pyparsing==3.2.3
# remote:  + pyrofork==2.3.68
# remote:  + pyshorteners==1.0.1
# remote:  + pysocks==1.7.1
# remote:  + pytdbot==0.9.5
# remote:  + python-magic==0.4.27
# remote:  + pytz==2025.2
# remote:  + requests==2.32.5
# remote:  + requests-oauthlib==2.0.0
# remote:  + requests-toolbelt==1.0.0
# remote:  + rsa==4.9.1
# remote:  + sgmllib3k==1.0.0
# remote:  + sniffio==1.3.1
# remote:  + speedtest-cli==2.1.3
# remote:  + starlette==0.47.2
# remote:  + tdjson==1.8.52
# remote:  + telegraph==2.2.0
# remote:  + tenacity==9.1.2
# remote:  + truelink==1.4.3
# remote:  + typing-extensions==4.14.1
# remote:  + typing-inspection==0.4.1
# remote:  + tzlocal==5.3.1
# remote:  + uritemplate==4.2.0
# remote:  + urllib3==2.5.0
# remote:  + uvicorn==0.35.0
# remote:  + uvloop==0.21.0
# remote:  + websockets==15.0.1
# remote:  + xattr==1.2.0
# remote:  + yarl==1.20.1
# remote:  + yt-dlp==2025.8.22
# remote: Removing intermediate container 0445e971b9e3
# remote:  ---> 18eb828dae3f
# remote: Step 7/8 : COPY . .
# remote:  ---> fd4204d61b7a
# remote: Step 8/8 : CMD ["bash", "start.sh"]
# remote:  ---> Running in 578a506686bb
# remote: Removing intermediate container 578a506686bb
# remote:  ---> c0eeff258fca
# remote: Successfully built c0eeff258fca
# remote: Successfully tagged 673c5398c5ea0881c0e2de67fa6abe7ac4e970e4:latest
# remote:
# remote: === Pushing web (Dockerfile)
# remote: Tagged image "673c5398c5ea0881c0e2de67fa6abe7ac4e970e4" as "registry.heroku.com/sfwaeonaug1/web"
# remote: Using default tag: latest
# remote: The push refers to repository [registry.heroku.com/sfwaeonaug1/web]
# remote: 6fc6c6f6a215: Preparing
# remote: 4105adf85fbc: Preparing
# remote: 4fa4fd9c306d: Preparing
# remote: 341f54ba0cc8: Preparing
# remote: 92cbf18eae6d: Preparing
# remote: 33344fdfeb99: Preparing
# remote: 1764d1568ba5: Preparing
# remote: bdae0ae96ee1: Preparing
# remote: 650f17506797: Preparing
# remote: 33344fdfeb99: Waiting
# remote: 1764d1568ba5: Waiting
# remote: bdae0ae96ee1: Waiting
# remote: 650f17506797: Waiting
# remote: 6fc6c6f6a215: Pushed
# remote: 92cbf18eae6d: Pushed
# remote: 4fa4fd9c306d: Pushed
# remote: 341f54ba0cc8: Pushed
# remote: 1764d1568ba5: Layer already exists
# remote: bdae0ae96ee1: Layer already exists
# remote: 33344fdfeb99: Pushed
# remote: 650f17506797: Pushed
# remote: 4105adf85fbc: Pushed
# remote: latest: digest: sha256:e6e1204f8a8cabb8e8852b8059c407e7b80bd24dec69e3fef0f6310a2d4838f2 size: 2200
# remote:
# remote: =!= Build failed due to an error:
# remote:
# remote: =!= release step: unexpected formation update response: id=delinquent message=We suspended this application. Contact the app owner.
# remote:
# remote: If this persists, please contact us at https://help.heroku.com/.
# remote: Verifying deploy...
# remote:
# remote: !	Push rejected to sfwaeonaug1.
# remote:
# To https://git.heroku.com/sfwaeonaug1.git
#  ! [remote rejected] deploy_main -> main (pre-receive hook declined)
# error: failed to push some refs to 'https://git.heroku.com/sfwaeonaug1.git'
#     Error: Type web not found in process formation.
#     Types:
# 🎉 Deployment completed! Your Aeon-MLTB bot should be starting up.

# %%
# @title <center><h2>📋 View App Logs</h2></center><br>

# @markdown <div align="center"><h3>🔍 Monitor your deployment</h3></div>
# @markdown <p align="center"><i>Check the logs to see if your bot is running properly</i></p>

# @markdown ---

App_Name = ""  # @param {type:"string"}
# @markdown <small>Enter your app name to view logs</small>

# @markdown ---

# !heroku logs -a {App_Name} --tail

# %%
# @title <center><h2>🔓 Heroku Logout</h2></center><br>

# @markdown <div align="center"><h3>🛡️ Security cleanup</h3></div>
# @markdown <p align="center"><i>Logout from Heroku for security</i></p>

# @markdown ---

# !heroku logout
print("✅ Successfully logged out from Heroku!")
print("🎉 Your Aeon-MLTB bot deployment is complete!")
print("📱 You can now use your bot on Telegram.")
